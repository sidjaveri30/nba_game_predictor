# %%
import pandas as pd

# %%
df = pd.read_csv("nba_games.csv", index_col = 0)

# %%
df.rename(columns={"Season": "season"}, inplace=True)

# %%
df
# Out:
#           mp   mp.1    fg    fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0      240.0  240.0  39.0   81.0  0.481   6.0  20.0  0.300  14.0  18.0  ...
# 1      240.0  240.0  36.0  100.0  0.360   7.0  31.0  0.226  16.0  19.0  ...
# 2      240.0  240.0  37.0   85.0  0.435   8.0  19.0  0.421  17.0  23.0  ...
# 3      240.0  240.0  41.0   89.0  0.461   8.0  21.0  0.381  17.0  19.0  ...
# 4      240.0  240.0  27.0   86.0  0.314   6.0  26.0  0.231  15.0  20.0  ...
# ...      ...    ...   ...    ...    ...   ...   ...    ...   ...   ...  ...
# 17749  240.0  240.0  35.0   81.0  0.432  11.0  26.0  0.423  27.0  36.0  ...
# 17750  240.0  240.0  37.0   74.0  0.500  13.0  25.0  0.520  26.0  37.0  ...
# 17751  240.0  240.0  42.0   89.0  0.472  14.0  33.0  0.424  10.0  20.0  ...
# 17752  240.0  240.0  41.0   85.0  0.482   9.0  26.0  0.346  26.0  30.0  ...
# 17753  240.0  240.0  33.0   85.0  0.388  12.0  44.0  0.273  28.0  34.0  ...
#
#        tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0              22.8          29.0         178.0         111.0       DAL
# 1              50.0          32.6         152.0         111.0       ATL
# 2              20.0          30.9         148.0         116.0       SAS
# 3              28.6          30.9         138.0         118.0       MIN
# 4              16.8          30.9         157.0          90.0       MEM
# ...             ...           ...           ...           ...       ...
# 17749          34.2          33.7         160.0         118.0       OKC
# 17750          25.0          30.0         139.0         129.0       ORL
# 17751          25.6          29.9         175.0         126.0       LAC
# 17752          27.7          27.1         150.0         126.0       MIA
# 17753          51.5          36.2         141.0         114.0       BOS
#
#        total_opp  home_opp  season        date    won
# 0             95         1    2016  2015-12-09   True
# 1             98         0    2016  2015-12-09  False
# 2            107         1    2018  2017-10-18  False
# 3             99         0    2018  2017-10-18   True
# 4             92         1    2021  2021-04-30  False
# ...          ...       ...     ...         ...    ...
# 17749         92         0    2019  2018-10-19   True
# 17750        108         1    2017  2016-12-14   True
# 17751        113         0    2017  2016-12-14  False
# 17752        106         1    2020  2020-09-19   True
# 17753        117         0    2020  2020-09-19  False
#
# [17754 rows x 154 columns]

# %%
df = df.sort_values("date")

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#           mp   mp.1    fg   fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0      240.0  240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  ...
# 1      240.0  240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  ...
# 2      240.0  240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  ...
# 3      240.0  240.0  37.0  96.0  0.385  12.0  29.0  0.414  20.0  26.0  ...
# 4      240.0  240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0  ...
# ...      ...    ...   ...   ...    ...   ...   ...    ...   ...   ...  ...
# 17749  240.0  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0  ...
# 17750  240.0  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0  ...
# 17751  240.0  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0  ...
# 17752  240.0  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0  ...
# 17753  240.0  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0  ...
#
#        tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0              69.4          43.7         206.0         104.0       GSW
# 1              53.2          34.6         162.0         104.0       CHI
# 2              33.3          23.6         132.0         104.0       DET
# 3              57.1          33.8         258.0         121.0       ATL
# 4              37.5          38.9         201.0         120.0       NOP
# ...             ...           ...           ...           ...       ...
# 17749          42.9          36.3         133.0         112.0       GSW
# 17750          33.3          36.2         222.0         107.0       GSW
# 17751          45.0          94.4         300.0         112.0       BOS
# 17752          33.3          31.5         186.0         111.0       GSW
# 17753         100.0          42.6         141.0         126.0       BOS
#
#        total_opp  home_opp  season        date    won
# 0            111         1    2016  2015-10-27  False
# 1             97         1    2016  2015-10-27  False
# 2            106         0    2016  2015-10-27  False
# 3             94         1    2016  2015-10-27   True
# 4             95         0    2016  2015-10-27   True
# ...          ...       ...     ...         ...    ...
# 17749        107         0    2022  2022-06-10  False
# 17750        104         1    2022  2022-06-13  False
# 17751         94         0    2022  2022-06-13   True
# 17752        103         0    2022  2022-06-16  False
# 17753         90         1    2022  2022-06-16   True
#
# [17754 rows x 154 columns]

# %%
del df["mp.1"]
del df["mp_opp.1"]
del df["index_opp"]

# %%
df
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0      240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704  ...
# 1      240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  ...
# 2      240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  0.800  ...
# 3      240.0  37.0  96.0  0.385  12.0  29.0  0.414  20.0  26.0  0.769  ...
# 4      240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0  0.909  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17749  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0  0.737  ...
# 17750  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0  0.677  ...
# 17751  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0  0.867  ...
# 17752  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0  0.917  ...
# 17753  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0  1.000  ...
#
#        tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0              69.4          43.7         206.0         104.0       GSW
# 1              53.2          34.6         162.0         104.0       CHI
# 2              33.3          23.6         132.0         104.0       DET
# 3              57.1          33.8         258.0         121.0       ATL
# 4              37.5          38.9         201.0         120.0       NOP
# ...             ...           ...           ...           ...       ...
# 17749          42.9          36.3         133.0         112.0       GSW
# 17750          33.3          36.2         222.0         107.0       GSW
# 17751          45.0          94.4         300.0         112.0       BOS
# 17752          33.3          31.5         186.0         111.0       GSW
# 17753         100.0          42.6         141.0         126.0       BOS
#
#        total_opp  home_opp  season        date    won
# 0            111         1    2016  2015-10-27  False
# 1             97         1    2016  2015-10-27  False
# 2            106         0    2016  2015-10-27  False
# 3             94         1    2016  2015-10-27   True
# 4             95         0    2016  2015-10-27   True
# ...          ...       ...     ...         ...    ...
# 17749        107         0    2022  2022-06-10  False
# 17750        104         1    2022  2022-06-13  False
# 17751         94         0    2022  2022-06-13   True
# 17752        103         0    2022  2022-06-16  False
# 17753         90         1    2022  2022-06-16   True
#
# [17754 rows x 151 columns]

# %%
def add_target(team):
    team["target"] = team["won"].shift(-1)
    return team

df = df.groupby("team", group_keys=False).apply(add_target)
# Out:
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1127067056.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   team["target"] = team["won"].shift(-1)

# %%
df[df["team"] == "WAS"]
# Out:
#           mp    fg    fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 15     240.0  33.0   84.0  0.393   7.0  28.0  0.250  15.0  25.0  0.600  ...
# 43     240.0  35.0   68.0  0.515  12.0  21.0  0.571  36.0  44.0  0.818  ...
# 70     240.0  38.0   90.0  0.422   6.0  22.0  0.273  28.0  33.0  0.848  ...
# 122    240.0  42.0   87.0  0.483   8.0  23.0  0.348  10.0  14.0  0.714  ...
# 155    240.0  36.0   88.0  0.409   8.0  25.0  0.320  18.0  23.0  0.783  ...
# ...      ...   ...    ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17439  240.0  38.0   82.0  0.463   8.0  21.0  0.381  18.0  20.0  0.900  ...
# 17468  240.0  56.0  101.0  0.554  13.0  30.0  0.433   7.0  14.0  0.500  ...
# 17489  240.0  42.0   86.0  0.488  10.0  35.0  0.286   9.0  11.0  0.818  ...
# 17520  240.0  35.0   69.0  0.507   9.0  28.0  0.321  13.0  17.0  0.765  ...
# 17559  240.0  42.0   94.0  0.447   8.0  23.0  0.348  16.0  26.0  0.615  ...
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 15             25.2         134.0          98.0       ORL         87
# 43             32.4         138.0         122.0       MIL        113
# 70             28.7         153.0         108.0       NYK        117
# 122            30.0         160.0         109.0       SAS         99
# 155            41.6         146.0         103.0       BOS        118
# ...             ...           ...           ...       ...        ...
# 17439          34.4         245.0         116.0       BOS        144
# 17468          32.8         168.0         132.0       MIN        114
# 17489          60.2         159.0         114.0       ATL        118
# 17520          35.5         135.0         104.0       NYK        114
# 17559          37.3         161.0         118.0       CHO        124
#
#        home_opp  season        date    won  target
# 15            1    2016  2015-10-28   True    True
# 43            1    2016  2015-10-30   True   False
# 70            0    2016  2015-10-31  False    True
# 122           0    2016  2015-11-04   True   False
# 155           1    2016  2015-11-06  False   False
# ...         ...     ...         ...    ...     ...
# 17439         1    2022  2022-04-03  False    True
# 17468         1    2022  2022-04-05   True   False
# 17489         1    2022  2022-04-06  False   False
# 17520         0    2022  2022-04-08  False   False
# 17559         1    2022  2022-04-10  False     NaN
#
# [579 rows x 152 columns]

# %%
df["target"][pd.isnull(df["target"])] = 2
# Out:
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/1618397414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["target"][pd.isnull(df["target"])] = 2

# %%
df["target"] =  df["target"].astype(int, errors="ignore")

# %%
df
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0      240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704  ...
# 1      240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  ...
# 2      240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  0.800  ...
# 3      240.0  37.0  96.0  0.385  12.0  29.0  0.414  20.0  26.0  0.769  ...
# 4      240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0  0.909  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17749  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0  0.737  ...
# 17750  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0  0.677  ...
# 17751  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0  0.867  ...
# 17752  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0  0.917  ...
# 17753  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0  1.000  ...
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 0              43.7         206.0         104.0       GSW        111
# 1              34.6         162.0         104.0       CHI         97
# 2              23.6         132.0         104.0       DET        106
# 3              33.8         258.0         121.0       ATL         94
# 4              38.9         201.0         120.0       NOP         95
# ...             ...           ...           ...       ...        ...
# 17749          36.3         133.0         112.0       GSW        107
# 17750          36.2         222.0         107.0       GSW        104
# 17751          94.4         300.0         112.0       BOS         94
# 17752          31.5         186.0         111.0       GSW        103
# 17753          42.6         141.0         126.0       BOS         90
#
#        home_opp  season        date    won  target
# 0             1    2016  2015-10-27  False       0
# 1             1    2016  2015-10-27  False       1
# 2             0    2016  2015-10-27  False       1
# 3             1    2016  2015-10-27   True       1
# 4             0    2016  2015-10-27   True       1
# ...         ...     ...         ...    ...     ...
# 17749         0    2022  2022-06-10  False       0
# 17750         1    2022  2022-06-13  False       0
# 17751         0    2022  2022-06-13   True       1
# 17752         0    2022  2022-06-16  False       2
# 17753         1    2022  2022-06-16   True       2
#
# [17754 rows x 152 columns]

# %%
df["won"].value_counts()
# Out:
# won
# False    8877
# True     8877
# Name: count, dtype: int64

# %%
df["target"].value_counts()
# Out:
# target
# 1    8863
# 0    8861
# 2      30
# Name: count, dtype: int64

# %%
nulls = pd.isnull(df)

# %%
nulls = nulls.sum()

# %%
nulls = nulls[nulls > 0]

# %%
valid_columns = df.columns[~df.columns.isin(nulls.index)]

# %%
valid_columns
# Out:
# Index(['mp', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%', 'ft', 'fta', 'ft%',
#        ...
#        'usg%_max_opp', 'ortg_max_opp', 'drtg_max_opp', 'team_opp', 'total_opp',
#        'home_opp', 'season', 'date', 'won', 'target'],
#       dtype='object', length=144)

# %%
df = df[valid_columns].copy()

# %%
df
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0      240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704  ...
# 1      240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  ...
# 2      240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  0.800  ...
# 3      240.0  37.0  96.0  0.385  12.0  29.0  0.414  20.0  26.0  0.769  ...
# 4      240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0  0.909  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17749  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0  0.737  ...
# 17750  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0  0.677  ...
# 17751  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0  0.867  ...
# 17752  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0  0.917  ...
# 17753  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0  1.000  ...
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 0              43.7         206.0         104.0       GSW        111
# 1              34.6         162.0         104.0       CHI         97
# 2              23.6         132.0         104.0       DET        106
# 3              33.8         258.0         121.0       ATL         94
# 4              38.9         201.0         120.0       NOP         95
# ...             ...           ...           ...       ...        ...
# 17749          36.3         133.0         112.0       GSW        107
# 17750          36.2         222.0         107.0       GSW        104
# 17751          94.4         300.0         112.0       BOS         94
# 17752          31.5         186.0         111.0       GSW        103
# 17753          42.6         141.0         126.0       BOS         90
#
#        home_opp  season        date    won  target
# 0             1    2016  2015-10-27  False       0
# 1             1    2016  2015-10-27  False       1
# 2             0    2016  2015-10-27  False       1
# 3             1    2016  2015-10-27   True       1
# 4             0    2016  2015-10-27   True       1
# ...         ...     ...         ...    ...     ...
# 17749         0    2022  2022-06-10  False       0
# 17750         1    2022  2022-06-13  False       0
# 17751         0    2022  2022-06-13   True       1
# 17752         0    2022  2022-06-16  False       2
# 17753         1    2022  2022-06-16   True       2
#
# [17754 rows x 144 columns]

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import RidgeClassifier

rr = RidgeClassifier(alpha=1)
split = TimeSeriesSplit(n_splits=3)
sfs = SequentialFeatureSelector(rr, n_features_to_select=30, direction="forward", cv=split)

# %%
removed_columns = ["season", "date", "won", "target", "team", "team_opp"]

# %%
selected_columns = df.columns[~df.columns.isin(removed_columns)]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[selected_columns] = scaler.fit_transform(df[selected_columns])

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0  0.363636  0.338235  0.366029  0.206897  0.212121  0.395487
# 1      0.0  0.431818  0.500000  0.322967  0.310345  0.378788  0.368171
# 2      0.0  0.409091  0.323529  0.435407  0.275862  0.348485  0.351544
# 3      0.0  0.409091  0.529412  0.277512  0.413793  0.378788  0.491686
# 4      0.0  0.500000  0.529412  0.377990  0.310345  0.393939  0.356295
# ...    ...       ...       ...       ...       ...       ...       ...
# 17749  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17750  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17751  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17752  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17753  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  usg%_max_opp  ortg_max_opp  \
# 0      0.418605  0.412698  0.654609  ...      0.277279      0.554502
# 1      0.209302  0.253968  0.519253  ...      0.160462      0.345972
# 2      0.255814  0.222222  0.766628  ...      0.019255      0.203791
# 3      0.441860  0.396825  0.730455  ...      0.150193      0.800948
# 4      0.441860  0.333333  0.893816  ...      0.215661      0.530806
# ...         ...       ...       ...  ...           ...           ...
# 17749  0.302326  0.285714  0.693116  ...      0.182285      0.208531
# 17750  0.465116  0.476190  0.623104  ...      0.181001      0.630332
# 17751  0.279070  0.222222  0.844807  ...      0.928113      1.000000
# 17752  0.232558  0.174603  0.903151  ...      0.120668      0.459716
# 17753  0.162791  0.111111  1.000000  ...      0.263158      0.246445
#
#        drtg_max_opp  team_opp  total_opp  home_opp  season        date    won  \
# 0          0.317647       GSW   0.451923       1.0    2016  2015-10-27  False
# 1          0.317647       CHI   0.317308       1.0    2016  2015-10-27  False
# 2          0.317647       DET   0.403846       0.0    2016  2015-10-27  False
# 3          0.517647       ATL   0.288462       1.0    2016  2015-10-27   True
# 4          0.505882       NOP   0.298077       0.0    2016  2015-10-27   True
# ...             ...       ...        ...       ...     ...         ...    ...
# 17749      0.411765       GSW   0.413462       0.0    2022  2022-06-10  False
# 17750      0.352941       GSW   0.384615       1.0    2022  2022-06-13  False
# 17751      0.411765       BOS   0.288462       0.0    2022  2022-06-13   True
# 17752      0.400000       GSW   0.375000       0.0    2022  2022-06-16  False
# 17753      0.576471       BOS   0.250000       1.0    2022  2022-06-16   True
#
#        target
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 17749       0
# 17750       0
# 17751       1
# 17752       2
# 17753       2
#
# [17754 rows x 144 columns]

# %%
sfs.fit(df[selected_columns], df["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=30)

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
predictors
# Out:
# ['mp',
#  '3p%',
#  'ft%',
#  'orb',
#  'drb',
#  'trb',
#  'pf',
#  'usg%',
#  'ft_max',
#  'trb_max',
#  'pf_max',
#  '+/-_max',
#  'ts%_max',
#  'drb%_max',
#  'blk%_max',
#  'tov%_max',
#  'ortg_max',
#  'mp_opp',
#  'blk_opp',
#  'ts%_opp',
#  'usg%_opp',
#  'ft_max_opp',
#  'stl_max_opp',
#  'blk_max_opp',
#  'pf_max_opp',
#  'pts_max_opp',
#  'gmsc_max_opp',
#  'drb%_max_opp',
#  'ast%_max_opp',
#  'stl%_max_opp']

# %%
def backtest(data, model, predictors, start=2, step=1):
    all_predictions = []

    seasons = sorted(data["season"].unique())

    for i in range(start, len(seasons), step):
        season = seasons[i]

        train = data[data["season"] < season]
        test = data[data["season"] == season]

        model.fit(train[predictors], train["target"])

        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)

        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]

        all_predictions.append(combined)

    return pd.concat(all_predictions)

# %%
predictions = backtest(df, rr, predictors)

# %%
predictions
# Out:
#        actual  prediction
# 5250        0           0
# 5251        1           0
# 5252        1           0
# 5253        1           1
# 5254        1           0
# ...       ...         ...
# 17749       0           0
# 17750       0           1
# 17751       1           0
# 17752       2           0
# 17753       2           0
#
# [12504 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score

predictions = predictions[predictions["actual"] != 2]
accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.5483405483405484

# %%
df.groupby("home").apply(lambda x: x[x["won"] == 1].shape[0] / x.shape[0])
# Out:
# home
# 0.0    0.428298
# 1.0    0.571702
# dtype: float64

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0  0.363636  0.338235  0.366029  0.206897  0.212121  0.395487
# 1      0.0  0.431818  0.500000  0.322967  0.310345  0.378788  0.368171
# 2      0.0  0.409091  0.323529  0.435407  0.275862  0.348485  0.351544
# 3      0.0  0.409091  0.529412  0.277512  0.413793  0.378788  0.491686
# 4      0.0  0.500000  0.529412  0.377990  0.310345  0.393939  0.356295
# ...    ...       ...       ...       ...       ...       ...       ...
# 17749  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17750  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17751  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17752  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17753  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  usg%_max_opp  ortg_max_opp  \
# 0      0.418605  0.412698  0.654609  ...      0.277279      0.554502
# 1      0.209302  0.253968  0.519253  ...      0.160462      0.345972
# 2      0.255814  0.222222  0.766628  ...      0.019255      0.203791
# 3      0.441860  0.396825  0.730455  ...      0.150193      0.800948
# 4      0.441860  0.333333  0.893816  ...      0.215661      0.530806
# ...         ...       ...       ...  ...           ...           ...
# 17749  0.302326  0.285714  0.693116  ...      0.182285      0.208531
# 17750  0.465116  0.476190  0.623104  ...      0.181001      0.630332
# 17751  0.279070  0.222222  0.844807  ...      0.928113      1.000000
# 17752  0.232558  0.174603  0.903151  ...      0.120668      0.459716
# 17753  0.162791  0.111111  1.000000  ...      0.263158      0.246445
#
#        drtg_max_opp  team_opp  total_opp  home_opp  season        date    won  \
# 0          0.317647       GSW   0.451923       1.0    2016  2015-10-27  False
# 1          0.317647       CHI   0.317308       1.0    2016  2015-10-27  False
# 2          0.317647       DET   0.403846       0.0    2016  2015-10-27  False
# 3          0.517647       ATL   0.288462       1.0    2016  2015-10-27   True
# 4          0.505882       NOP   0.298077       0.0    2016  2015-10-27   True
# ...             ...       ...        ...       ...     ...         ...    ...
# 17749      0.411765       GSW   0.413462       0.0    2022  2022-06-10  False
# 17750      0.352941       GSW   0.384615       1.0    2022  2022-06-13  False
# 17751      0.411765       BOS   0.288462       0.0    2022  2022-06-13   True
# 17752      0.400000       GSW   0.375000       0.0    2022  2022-06-16  False
# 17753      0.576471       BOS   0.250000       1.0    2022  2022-06-16   True
#
#        target
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 17749       0
# 17750       0
# 17751       1
# 17752       2
# 17753       2
#
# [17754 rows x 144 columns]

# %%
df_rolling = df[list(selected_columns) + ["won", "team", "season"]]

def find_team_averages(team):
    rolling = team.loc[:, team.columns != 'team'].rolling(10).mean()
    rolling[['team', 'season', 'won']] = team[['team', 'season', 'won']]
    
    return rolling

df_rolling = df_rolling.groupby(["team", "season"], group_keys=False).apply(find_team_averages)

# %%
df_rolling
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...    ...       ...       ...       ...       ...       ...       ...
# 17749  0.0  0.381818  0.292647  0.428230  0.468966  0.477273  0.448100
# 17750  0.0  0.354545  0.279412  0.404545  0.437931  0.465152  0.429572
# 17751  0.0  0.502273  0.364706  0.517703  0.455172  0.481818  0.440736
# 17752  0.0  0.354545  0.294118  0.389952  0.434483  0.459091  0.431710
# 17753  0.0  0.484091  0.379412  0.482297  0.486207  0.507576  0.448812
#
#              ft       fta       ft%  ...  blk%_max_opp  tov%_max_opp  \
# 0           NaN       NaN       NaN  ...           NaN           NaN
# 1           NaN       NaN       NaN  ...           NaN           NaN
# 2           NaN       NaN       NaN  ...           NaN           NaN
# 3           NaN       NaN       NaN  ...           NaN           NaN
# 4           NaN       NaN       NaN  ...           NaN           NaN
# ...         ...       ...       ...  ...           ...           ...
# 17749  0.434884  0.373016  0.764177  ...        0.1113      0.471908
# 17750  0.434884  0.385714  0.736639  ...        0.1113      0.483229
# 17751  0.320930  0.282540  0.757993  ...        0.1171      0.374109
# 17752  0.406977  0.357143  0.754142  ...        0.1111      0.483229
# 17753  0.316279  0.269841  0.801750  ...        0.1152      0.444025
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  total_opp  home_opp    won  \
# 0               NaN           NaN           NaN        NaN       NaN  False
# 1               NaN           NaN           NaN        NaN       NaN  False
# 2               NaN           NaN           NaN        NaN       NaN  False
# 3               NaN           NaN           NaN        NaN       NaN   True
# 4               NaN           NaN           NaN        NaN       NaN   True
# ...             ...           ...           ...        ...       ...    ...
# 17749      0.170603      0.431754      0.522353   0.348077       0.5  False
# 17750      0.174711      0.438863      0.483529   0.350000       0.5  False
# 17751      0.321566      0.642654      0.564706   0.392308       0.4   True
# 17752      0.172144      0.460190      0.472941   0.344231       0.5  False
# 17753      0.308601      0.628910      0.568235   0.395192       0.5   True
#
#        season  team
# 0        2016   NOP
# 1        2016   CLE
# 2        2016   ATL
# 3        2016   DET
# 4        2016   GSW
# ...       ...   ...
# 17749    2022   BOS
# 17750    2022   BOS
# 17751    2022   GSW
# 17752    2022   BOS
# 17753    2022   GSW
#
# [17754 rows x 141 columns]

# %%
rolling_cols = [f"{col}_10" for col in df_rolling.columns]
df_rolling.columns = rolling_cols

df = pd.concat([df, df_rolling], axis=1)

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0  0.363636  0.338235  0.366029  0.206897  0.212121  0.395487
# 1      0.0  0.431818  0.500000  0.322967  0.310345  0.378788  0.368171
# 2      0.0  0.409091  0.323529  0.435407  0.275862  0.348485  0.351544
# 3      0.0  0.409091  0.529412  0.277512  0.413793  0.378788  0.491686
# 4      0.0  0.500000  0.529412  0.377990  0.310345  0.393939  0.356295
# ...    ...       ...       ...       ...       ...       ...       ...
# 17749  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17750  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17751  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17752  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17753  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  blk%_max_opp_10  tov%_max_opp_10  \
# 0      0.418605  0.412698  0.654609  ...              NaN              NaN
# 1      0.209302  0.253968  0.519253  ...              NaN              NaN
# 2      0.255814  0.222222  0.766628  ...              NaN              NaN
# 3      0.441860  0.396825  0.730455  ...              NaN              NaN
# 4      0.441860  0.333333  0.893816  ...              NaN              NaN
# ...         ...       ...       ...  ...              ...              ...
# 17749  0.302326  0.285714  0.693116  ...           0.1113         0.471908
# 17750  0.465116  0.476190  0.623104  ...           0.1113         0.483229
# 17751  0.279070  0.222222  0.844807  ...           0.1171         0.374109
# 17752  0.232558  0.174603  0.903151  ...           0.1111         0.483229
# 17753  0.162791  0.111111  1.000000  ...           0.1152         0.444025
#
#        usg%_max_opp_10  ortg_max_opp_10  drtg_max_opp_10  total_opp_10  \
# 0                  NaN              NaN              NaN           NaN
# 1                  NaN              NaN              NaN           NaN
# 2                  NaN              NaN              NaN           NaN
# 3                  NaN              NaN              NaN           NaN
# 4                  NaN              NaN              NaN           NaN
# ...                ...              ...              ...           ...
# 17749         0.170603         0.431754         0.522353      0.348077
# 17750         0.174711         0.438863         0.483529      0.350000
# 17751         0.321566         0.642654         0.564706      0.392308
# 17752         0.172144         0.460190         0.472941      0.344231
# 17753         0.308601         0.628910         0.568235      0.395192
#
#        home_opp_10  won_10  season_10  team_10
# 0              NaN   False       2016      NOP
# 1              NaN   False       2016      CLE
# 2              NaN   False       2016      ATL
# 3              NaN    True       2016      DET
# 4              NaN    True       2016      GSW
# ...            ...     ...        ...      ...
# 17749          0.5   False       2022      BOS
# 17750          0.5   False       2022      BOS
# 17751          0.4    True       2022      GSW
# 17752          0.5   False       2022      BOS
# 17753          0.5    True       2022      GSW
#
# [17754 rows x 285 columns]

# %%
df = df.dropna()

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 236    0.0  0.522727  0.382353  0.523923  0.344828  0.333333  0.457245
# 247    0.0  0.659091  0.426471  0.645933  0.620690  0.515152  0.562945
# 252    0.0  0.386364  0.235294  0.490431  0.206897  0.242424  0.356295
# 253    0.0  0.318182  0.132353  0.500000  0.275862  0.272727  0.432304
# 255    0.0  0.340909  0.250000  0.413876  0.310345  0.257576  0.509501
# ...    ...       ...       ...       ...       ...       ...       ...
# 17749  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17750  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17751  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17752  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17753  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  blk%_max_opp_10  tov%_max_opp_10  \
# 236    0.255814  0.238095  0.708285  ...           0.0679         0.413522
# 247    0.325581  0.238095  0.927655  ...           0.0772         0.469497
# 252    0.325581  0.301587  0.708285  ...           0.0735         0.409119
# 253    0.581395  0.444444  0.879813  ...           0.0982         0.313312
# 255    0.511628  0.412698  0.827305  ...           0.1072         0.380294
# ...         ...       ...       ...  ...              ...              ...
# 17749  0.302326  0.285714  0.693116  ...           0.1113         0.471908
# 17750  0.465116  0.476190  0.623104  ...           0.1113         0.483229
# 17751  0.279070  0.222222  0.844807  ...           0.1171         0.374109
# 17752  0.232558  0.174603  0.903151  ...           0.1111         0.483229
# 17753  0.162791  0.111111  1.000000  ...           0.1152         0.444025
#
#        usg%_max_opp_10  ortg_max_opp_10  drtg_max_opp_10  total_opp_10  \
# 236           0.124134         0.361611         0.449412      0.347115
# 247           0.219641         0.394787         0.531765      0.324038
# 252           0.134531         0.363507         0.452941      0.347115
# 253           0.179974         0.500000         0.471765      0.380769
# 255           0.273427         0.270616         0.478824      0.308654
# ...                ...              ...              ...           ...
# 17749         0.170603         0.431754         0.522353      0.348077
# 17750         0.174711         0.438863         0.483529      0.350000
# 17751         0.321566         0.642654         0.564706      0.392308
# 17752         0.172144         0.460190         0.472941      0.344231
# 17753         0.308601         0.628910         0.568235      0.395192
#
#        home_opp_10  won_10  season_10  team_10
# 236            0.4    True       2016      ATL
# 247            0.5    True       2016      GSW
# 252            0.5   False       2016      ATL
# 253            0.5   False       2016      POR
# 255            0.6    True       2016      TOR
# ...            ...     ...        ...      ...
# 17749          0.5   False       2022      BOS
# 17750          0.5   False       2022      BOS
# 17751          0.4    True       2022      GSW
# 17752          0.5   False       2022      BOS
# 17753          0.5    True       2022      GSW
#
# [15864 rows x 285 columns]

# %%
def shift_col(team, col_name):
    next_col = team[col_name].shift(-1)
    return next_col

def add_col(df, col_name):
    return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))

df["home_next"] = add_col(df, "home")
df["team_opp_next"]= add_col(df, "team_opp")
df["date_next"] = add_col(df, "date")
# Out:
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/3005569186.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["home_next"] = add_col(df, "home")
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/3005569186.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["team_opp_next"]= add_col(df, "team_opp")
# /var/folders/59/_p4xf6cn2132b95vn_mr4ptw0000gn/T/ipykernel_9833/3005569186.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["date_next"] = add_col(df, "date")

# %%
df = df.copy()

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 236    0.0  0.522727  0.382353  0.523923  0.344828  0.333333  0.457245
# 247    0.0  0.659091  0.426471  0.645933  0.620690  0.515152  0.562945
# 252    0.0  0.386364  0.235294  0.490431  0.206897  0.242424  0.356295
# 253    0.0  0.318182  0.132353  0.500000  0.275862  0.272727  0.432304
# 255    0.0  0.340909  0.250000  0.413876  0.310345  0.257576  0.509501
# ...    ...       ...       ...       ...       ...       ...       ...
# 17749  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17750  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17751  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17752  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17753  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  ortg_max_opp_10  drtg_max_opp_10  \
# 236    0.255814  0.238095  0.708285  ...         0.361611         0.449412
# 247    0.325581  0.238095  0.927655  ...         0.394787         0.531765
# 252    0.325581  0.301587  0.708285  ...         0.363507         0.452941
# 253    0.581395  0.444444  0.879813  ...         0.500000         0.471765
# 255    0.511628  0.412698  0.827305  ...         0.270616         0.478824
# ...         ...       ...       ...  ...              ...              ...
# 17749  0.302326  0.285714  0.693116  ...         0.431754         0.522353
# 17750  0.465116  0.476190  0.623104  ...         0.438863         0.483529
# 17751  0.279070  0.222222  0.844807  ...         0.642654         0.564706
# 17752  0.232558  0.174603  0.903151  ...         0.460190         0.472941
# 17753  0.162791  0.111111  1.000000  ...         0.628910         0.568235
#
#        total_opp_10  home_opp_10  won_10  season_10  team_10  home_next  \
# 236        0.347115          0.4    True       2016      ATL        0.0
# 247        0.324038          0.5    True       2016      GSW        1.0
# 252        0.347115          0.5   False       2016      ATL        1.0
# 253        0.380769          0.5   False       2016      POR        0.0
# 255        0.308654          0.6    True       2016      TOR        0.0
# ...             ...          ...     ...        ...      ...        ...
# 17749      0.348077          0.5   False       2022      BOS        0.0
# 17750      0.350000          0.5   False       2022      BOS        1.0
# 17751      0.392308          0.4    True       2022      GSW        0.0
# 17752      0.344231          0.5   False       2022      BOS        NaN
# 17753      0.395192          0.5    True       2022      GSW        NaN
#
#        team_opp_next   date_next
# 236              BOS  2015-11-13
# 247              BRK  2015-11-14
# 252              UTA  2015-11-15
# 253              CHO  2015-11-15
# 255              SAC  2015-11-15
# ...              ...         ...
# 17749            GSW  2022-06-13
# 17750            GSW  2022-06-16
# 17751            BOS  2022-06-16
# 17752           None        None
# 17753           None        None
#
# [15864 rows x 288 columns]

# %%
full = df.merge(df[rolling_cols + ["team_opp_next", "date_next", "team"]], 
                left_on=["team", "date_next"], 
                right_on=["team_opp_next", "date_next"])

# %%
full[["team_x", "team_opp_next_x", "team_y", "team_opp_next_y", "date_next"]]
# Out:
#       team_x team_opp_next_x team_y team_opp_next_y   date_next
# 0        TOR             SAC    SAC             TOR  2015-11-15
# 1        SAC             TOR    TOR             SAC  2015-11-15
# 2        CLE             DET    DET             CLE  2015-11-17
# 3        ORL             MIN    MIN             ORL  2015-11-18
# 4        DEN             NOP    NOP             DEN  2015-11-17
# ...      ...             ...    ...             ...         ...
# 15751    BOS             GSW    GSW             BOS  2022-06-10
# 15752    GSW             BOS    BOS             GSW  2022-06-13
# 15753    BOS             GSW    GSW             BOS  2022-06-13
# 15754    BOS             GSW    GSW             BOS  2022-06-16
# 15755    GSW             BOS    BOS             GSW  2022-06-16
#
# [15756 rows x 5 columns]

# %%
removed_columns = list(full.columns[full.dtypes == "object"]) + removed_columns

# %%
removed_columns
# Out:
# ['team_x',
#  'team_opp',
#  'date',
#  'team_10_x',
#  'team_opp_next_x',
#  'date_next',
#  'team_10_y',
#  'team_opp_next_y',
#  'team_y',
#  'season',
#  'date',
#  'won',
#  'target',
#  'team',
#  'team_opp']

# %%
selected_columns = full.columns[~full.columns.isin(removed_columns)]

# %%
sfs.fit(full[selected_columns], full["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=30)

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
predictors
# Out:
# ['orb',
#  'tov%',
#  'usg%',
#  '3pa_max',
#  'trb_max',
#  'tov_max',
#  '3p_opp',
#  'usg%_opp',
#  'ft%_max_opp',
#  'pts_max_opp',
#  'gmsc_max_opp',
#  'ftr_max_opp',
#  'stl%_10_x',
#  'usg%_10_x',
#  'fga_max_10_x',
#  'trb_max_10_x',
#  'gmsc_max_10_x',
#  '+/-_max_10_x',
#  'ast%_opp_10_x',
#  'usg%_opp_10_x',
#  'fg%_max_opp_10_x',
#  'season_10_x',
#  'home_next',
#  'usg%_10_y',
#  'fg_max_10_y',
#  'trb_max_10_y',
#  'gmsc_max_10_y',
#  '+/-_max_10_y',
#  'usg%_opp_10_y',
#  'season_10_y']

# %%
predictions = backtest(full, rr, predictors)

# %%
accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.63155519451214
